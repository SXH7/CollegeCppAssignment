# %%
import numpy as np
A = np.array([[1,5],[2,3],[3,10]])
c = A.mean(0)
Ac = A - np.outer(np.ones(3),c)
C = np.eye(3) - np.ones(3)/3
Ac = C@A
print("A = ",A)
print("Ac =",Ac)
# Out:
# A =  [[ 1  5]
#  [ 2  3]
#  [ 3 10]]
# Ac = [[-1.00000000e+00 -1.00000000e+00]
#  [ 2.77555756e-16 -3.00000000e+00]
#  [ 1.00000000e+00  4.00000000e+00]]
